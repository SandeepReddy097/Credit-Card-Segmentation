# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('credit-card-data.csv')
data
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# 1                       0.00   6442.945483             0.000000
# 2                       0.00      0.000000             1.000000
# 3                       0.00    205.788017             0.083333
# 4                       0.00      0.000000             0.083333
# ...                      ...           ...                  ...
# 8945                  291.12      0.000000             1.000000
# 8946                  300.00      0.000000             1.000000
# 8947                  144.40      0.000000             0.833333
# 8948                    0.00     36.558778             0.000000
# 8949                    0.00    127.040008             0.666667
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                       0.000000                          0.083333
# 1                       0.000000                          0.000000
# 2                       1.000000                          0.000000
# 3                       0.083333                          0.000000
# 4                       0.083333                          0.000000
# ...                          ...                               ...
# 8945                    0.000000                          0.833333
# 8946                    0.000000                          0.833333
# 8947                    0.000000                          0.666667
# 8948                    0.000000                          0.000000
# 8949                    0.666667                          0.000000
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                   0.000000                 0              2        1000.0
# 1                   0.250000                 4              0        7000.0
# 2                   0.000000                 0             12        7500.0
# 3                   0.083333                 1              1        7500.0
# 4                   0.000000                 0              1        1200.0
# ...                      ...               ...            ...           ...
# 8945                0.000000                 0              6        1000.0
# 8946                0.000000                 0              6        1000.0
# 8947                0.000000                 0              5        1000.0
# 8948                0.166667                 2              0         500.0
# 8949                0.333333                 2             23        1200.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0      201.802084        139.509787          0.000000      12
# 1     4103.032597       1072.340217          0.222222      12
# 2      622.066742        627.284787          0.000000      12
# 3        0.000000               NaN          0.000000      12
# 4      678.334763        244.791237          0.000000      12
# ...           ...               ...               ...     ...
# 8945   325.594462         48.886365          0.500000       6
# 8946   275.861322               NaN          0.000000       6
# 8947    81.270775         82.418369          0.250000       6
# 8948    52.549959         55.755628          0.250000       6
# 8949    63.165404         88.288956          0.000000       6
#
# [8950 rows x 18 columns]

# %%
data.shape
# Out:
# (8950, 18)

# %%
data.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# 25%                  0.000000      0.000000             0.083333
# 50%                 89.000000      0.000000             0.500000
# 75%                468.637500   1113.821139             0.916667
# max              22500.000000  47137.211760             1.000000
#
#        ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# count                 8950.000000                       8950.000000
# mean                     0.202458                          0.364437
# std                      0.298336                          0.397448
# min                      0.000000                          0.000000
# 25%                      0.000000                          0.000000
# 50%                      0.083333                          0.166667
# 75%                      0.300000                          0.750000
# max                      1.000000                          1.000000
#
#        CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# count             8950.000000       8950.000000    8950.000000   8949.000000
# mean                 0.135144          3.248827      14.709832   4494.449450
# std                  0.200121          6.824647      24.857649   3638.815725
# min                  0.000000          0.000000       0.000000     50.000000
# 25%                  0.000000          0.000000       1.000000   1600.000000
# 50%                  0.000000          0.000000       7.000000   3000.000000
# 75%                  0.222222          4.000000      17.000000   6500.000000
# max                  1.500000        123.000000     358.000000  30000.000000
#
#            PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT       TENURE
# count   8950.000000       8637.000000       8950.000000  8950.000000
# mean    1733.143852        864.206542          0.153715    11.517318
# std     2895.063757       2372.446607          0.292499     1.338331
# min        0.000000          0.019163          0.000000     6.000000
# 25%      383.276166        169.123707          0.000000    12.000000
# 50%      856.901546        312.343947          0.000000    12.000000
# 75%     1901.134317        825.485459          0.142857    12.000000
# max    50721.483360      76406.207520          1.000000    12.000000

# %%
data.dtypes
# Out:
# CUST_ID                              object
# BALANCE                             float64
# BALANCE_FREQUENCY                   float64
# PURCHASES                           float64
# ONEOFF_PURCHASES                    float64
# INSTALLMENTS_PURCHASES              float64
# CASH_ADVANCE                        float64
# PURCHASES_FREQUENCY                 float64
# ONEOFF_PURCHASES_FREQUENCY          float64
# PURCHASES_INSTALLMENTS_FREQUENCY    float64
# CASH_ADVANCE_FREQUENCY              float64
# CASH_ADVANCE_TRX                      int64
# PURCHASES_TRX                         int64
# CREDIT_LIMIT                        float64
# PAYMENTS                            float64
# MINIMUM_PAYMENTS                    float64
# PRC_FULL_PAYMENT                    float64
# TENURE                                int64
# dtype: object

# %%
#data['PURCHASES_TRX'] = data['PURCHASES_TRX'].astype('float64')

# %% [markdown]
# ## Missing Value Analysis

# %%
def CalMissingValues(data):
    return data.isna().sum()

# %%
CalMissingValues(data)
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
# Calculating the Percentage of Missing Values in the dataset.
(CalMissingValues(data).sum()/data.shape[0])*100
# Out:
# 3.5083798882681565

# %% [markdown]
# Which means 3.5% rows of the data contain null values. We can impute them
# or else we can ignore them by not considering for analysis..

# %%
# Delete all rows even if it has a single null value
data = data.dropna(axis=0)
data.shape
# Out:
# (8636, 18)

# %% [markdown]
# # Deriving KPI's

# %% [markdown]
# ### Monthly Average Purchase & Cash Advanced Amount

# %%
data_KPI = pd.DataFrame()
data_KPI['CUST_ID'] = data['CUST_ID']

# %%
data_KPI['Monthly_Average_Purchase'] = data['PURCHASES']/data['TENURE']
data_KPI['Monthly_Cash_Advance'] = data['CASH_ADVANCE']/data['TENURE']

# %% [markdown]
# ### Purchases by Type
#
# Seeing the data, we can infer that there are two types of purchases.
# ONE_OFF_PURCHASE and INSTALLMENT_PURCHASE
#
#
# Lets Explore little more

# %%
a = data[(data['ONEOFF_PURCHASES'] == 0) & (data['INSTALLMENTS_PURCHASES'] == 0)]
aa = a.shape

# %%
print('So there are ' + str(aa[0]) + ' clients who do not make use of any type of purchases.')
# Out:
# So there are 1965 clients who do not make use of any type of purchases.

# %%
#bb = data[(data['ONEOFF_PURCHASES'] != 0) & (data['INSTALLMENTS_PURCHASES'] != 0)]
b = data[(data['ONEOFF_PURCHASES'] > 0) & (data['INSTALLMENTS_PURCHASES'] > 0)]
bb = b.shape

# %%
print("There are " + str(bb[0]) + " clients who make use of both the purchases.")
# Out:
# There are 2741 clients who make use of both the purchases.

# %%
c = data[(data['ONEOFF_PURCHASES'] > 0) & (data['INSTALLMENTS_PURCHASES'] == 0)]
cc = c.shape

# %%
print(str(cc[0]) + " clients make use of only ONEOFF_PURCHASES")
# Out:
# 1782 clients make use of only ONEOFF_PURCHASES

# %%
d = data[(data['ONEOFF_PURCHASES'] == 0) & (data['INSTALLMENTS_PURCHASES'] > 0)]
dd = d.shape

# %%
print(str(dd[0]) + " clients make use of INSTALLMENTS_PURCHASES")
# Out:
# 2148 clients make use of INSTALLMENTS_PURCHASES

# %% [markdown]
# ##### Result: We found that there are FOUR types of Purchase behaviour in the data.
#
# 1. People who does not make any purchases.
# 2. People who make both types of purchases.
# 3. People who make only OneOff_Purchases
# 4. People who make only Installment_Purchases

# %% [markdown]
# ###### User Defined Function to catogorise the purchase behaviour in the data

# %%
def purchaseType(data):
    if (data['ONEOFF_PURCHASES'] == 0) & (data['INSTALLMENTS_PURCHASES'] > 0) :
        return 'installment'
    if (data['ONEOFF_PURCHASES'] > 0) & (data['INSTALLMENTS_PURCHASES'] == 0) :
        return 'one_off'
    if (data['ONEOFF_PURCHASES'] > 0) & (data['INSTALLMENTS_PURCHASES'] > 0) :
        return 'both'
    if (data['ONEOFF_PURCHASES'] == 0) & (data['INSTALLMENTS_PURCHASES'] == 0) :
        return 'not any'

# %%
data_KPI['Purchase_Type'] = data.apply(purchaseType, axis = 1)

# %%
data_KPI
# Out:
#      CUST_ID  Monthly_Average_Purchase  Monthly_Cash_Advance Purchase_Type
# 0     C10001                  7.950000              0.000000   installment
# 1     C10002                  0.000000            536.912124       not any
# 2     C10003                 64.430833              0.000000       one_off
# 4     C10005                  1.333333              0.000000       one_off
# 5     C10006                111.106667              0.000000   installment
# ...      ...                       ...                   ...           ...
# 8943  C19184                  3.483333              0.000000       one_off
# 8945  C19186                 48.520000              0.000000   installment
# 8947  C19188                 24.066667              0.000000   installment
# 8948  C19189                  0.000000              6.093130       not any
# 8949  C19190                182.208333             21.173335       one_off
#
# [8636 rows x 4 columns]

# %%
Purchase_Types = data_KPI['Purchase_Type'].value_counts()
Purchase_Types
# Out:
# both           2741
# installment    2148
# not any        1965
# one_off        1782
# Name: Purchase_Type, dtype: int64

# %%
Purchase_Types.plot.bar()
plt.xlabel('Purchase Type')
plt.ylabel('Count')
plt.title('Distribution for Purchase Type')
plt.show()

# %% [markdown]
# ### Average Amount per Purchase & Average Cash Advanced Transaction

# %%
AvgAmtPerPurchase = data[['CUST_ID', 'PURCHASES_TRX']]
print(AvgAmtPerPurchase.describe())
AvgAmtPerPurchase[AvgAmtPerPurchase['PURCHASES_TRX'] > AvgAmtPerPurchase['PURCHASES_TRX'].quantile(0.75)]
# Out:
#        PURCHASES_TRX
# count    8636.000000
# mean       15.033233
# std        25.180468
# min         0.000000
# 25%         1.000000
# 50%         7.000000
# 75%        18.000000
# max       358.000000
#      CUST_ID  PURCHASES_TRX
# 6     C10007             64
# 12    C10013             26
# 13    C10014             26
# 21    C10022             92
# 30    C10031             64
# ...      ...            ...
# 8895  C19136             22
# 8897  C19138             26
# 8903  C19144             27
# 8923  C19164             24
# 8949  C19190             23
#
# [2086 rows x 2 columns]

# %% [markdown]
# 25% of clients Average Amount per Purchase is more than 18.
# Maximum is 358

# %%
AvgCashAdvance = data[['CUST_ID', 'CASH_ADVANCE_TRX']]
print(AvgCashAdvance.describe())
AvgCashAdvance[AvgCashAdvance['CASH_ADVANCE_TRX'] > AvgCashAdvance['CASH_ADVANCE_TRX'].quantile(0.75)]
# Out:
#        CASH_ADVANCE_TRX
# count       8636.000000
# mean           3.313918
# std            6.912506
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            4.000000
# max          123.000000
#      CUST_ID  CASH_ADVANCE_TRX
# 21    C10022                 6
# 23    C10024                13
# 26    C10027                 5
# 28    C10029                16
# 30    C10031                10
# ...      ...               ...
# 8915  C19156                16
# 8917  C19158                 5
# 8933  C19174                 5
# 8938  C19179                 7
# 8941  C19182                13
#
# [1961 rows x 2 columns]

# %% [markdown]
# 25% of clients Average Cash Advance is more than 4. Maximum is 123.

# %% [markdown]
# ### Limit Usage
#
# It's nothing but the Balance to credit card ratio.

# %%
data_KPI['Limit_Usage'] = data['BALANCE']/data['CREDIT_LIMIT']
data_KPI['Limit_Usage']
# Out:
# 0       0.040901
# 1       0.457495
# 2       0.332687
# 4       0.681429
# 5       1.005460
#           ...
# 8943    0.011743
# 8945    0.028494
# 8947    0.023399
# 8948    0.026915
# 8949    0.310590
# Name: Limit_Usage, Length: 8636, dtype: float64

# %% [markdown]
# ### Payments to Minimum Payments Ratio

# %%
data_KPI['Pymt_to_minPymt_Ratio'] = data['PAYMENTS']/data['MINIMUM_PAYMENTS']
data_KPI['Pymt_to_minPymt_Ratio']
# Out:
# 0       1.446508
# 1       3.826241
# 2       0.991682
# 4       2.771075
# 5       0.581601
#           ...
# 8943    1.348973
# 8945    6.660231
# 8947    0.986076
# 8948    0.942505
# 8949    0.715439
# Name: Pymt_to_minPymt_Ratio, Length: 8636, dtype: float64

# %% [markdown]
# ## Insights from new KPI's

# %%
# View the KPI's
data_KPI
# Out:
#      CUST_ID  Monthly_Average_Purchase  Monthly_Cash_Advance Purchase_Type  \
# 0     C10001                  7.950000              0.000000   installment
# 1     C10002                  0.000000            536.912124       not any
# 2     C10003                 64.430833              0.000000       one_off
# 4     C10005                  1.333333              0.000000       one_off
# 5     C10006                111.106667              0.000000   installment
# ...      ...                       ...                   ...           ...
# 8943  C19184                  3.483333              0.000000       one_off
# 8945  C19186                 48.520000              0.000000   installment
# 8947  C19188                 24.066667              0.000000   installment
# 8948  C19189                  0.000000              6.093130       not any
# 8949  C19190                182.208333             21.173335       one_off
#
#       Limit_Usage  Pymt_to_minPymt_Ratio
# 0        0.040901               1.446508
# 1        0.457495               3.826241
# 2        0.332687               0.991682
# 4        0.681429               2.771075
# 5        1.005460               0.581601
# ...           ...                    ...
# 8943     0.011743               1.348973
# 8945     0.028494               6.660231
# 8947     0.023399               0.986076
# 8948     0.026915               0.942505
# 8949     0.310590               0.715439
#
# [8636 rows x 6 columns]

# %%
# Average Payment_minPayment ratio for each purchase type
x = data_KPI.groupby('Purchase_Type').apply(lambda x : np.mean(x['Pymt_to_minPymt_Ratio']))
x
# Out:
# Purchase_Type
# both            7.314910
# installment    13.927398
# not any        10.464923
# one_off         5.738574
# dtype: float64

# %%
x.plot.bar()
plt.xlabel('Purchase_Type')
plt.ylabel('Pymt_to_minPymt_Ratio')
plt.title('Average Payment_minPayment ratio for each purchase type')
plt.show()

# %% [markdown]
# ### Insight 1: Clients with Purchase type Installment are with more Dues.

# %%
# Average Limit Usage for each purchase type
x1 = data_KPI.groupby('Purchase_Type').apply(lambda x : np.mean(x['Limit_Usage']))
x1
# Out:
# Purchase_Type
# both           0.354384
# installment    0.282141
# not any        0.589193
# one_off        0.392569
# dtype: float64

# %%
x1.plot.bar()
plt.xlabel('Purchase_Type')
plt.ylabel('Limit Usage')
plt.title('Average Limit Usage for each purchase type')
plt.show()

# %% [markdown]
# ### Insight 2: Clients with Purchase type Installment have good Credit Score

# %%
# Monthly Cash Advance for each purchase type
x2 = data_KPI.groupby('Purchase_Type').apply(lambda x : np.mean(x['Monthly_Cash_Advance']))
x2
# Out:
# Purchase_Type
# both            68.014265
# installment     40.066445
# not any        184.337290
# one_off         81.200749
# dtype: float64

# %%
x2.plot.bar()
plt.xlabel('Purchase_Type')
plt.ylabel('Monthly_Cash_Advanced')
plt.title('Average Monthly Cash Advance for each purchase type')
plt.show()

# %% [markdown]
# ### Insight 3: Clients who don't do any type of purchases(OneOff, Installments), Take more Cash On Advance

# %% [markdown]
# _________________________________________________________________________

# %% [markdown]
# # Clustering

# %% [markdown]
# ## Outlier Analysis

# %%
data.columns
# Out:
# Index(['CUST_ID', 'BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES',
#        'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE',
#        'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY',
#        'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY',
#        'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS',
#        'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'TENURE'],
#       dtype='object')

# %%
data[['BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES','ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE',
       'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY',
       'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY',
       'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS',
      'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'TENURE']].plot.box(figsize=(17,10), legend=True, title='Outlier Distribution')

# %%
data[['BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES',
       'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES',
      'CASH_ADVANCE']].plot.box(figsize=(17,10),legend=True, title='Outlier Distribution')

# %%
data[['PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY',
       'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY',
       'CASH_ADVANCE_TRX']].plot.box(figsize=(17,10),legend=True, title='Outlier Distribution')

# %%
data[['PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS',
       'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'TENURE']].plot.box(figsize=(17,10),legend=True, title='Outlier Distribution')

# %% [markdown]
# Since there are many outliers, if we remove them we will lose 90% of the data. We will keep them.

# %% [markdown]
# ## Feature Selection

# %%
correlation_matrix = data.corr()
correlation_matrix = pd.DataFrame(correlation_matrix)

# %%
# Plotting a heatmap
plt.figure(figsize=(20,10))
sns.heatmap(correlation_matrix, cmap='coolwarm', annot=True)
plt.title('Correlation', size = 28)
# Out:
# Text(0.5, 1, 'Correlation')

# %% [markdown]
# ##### To find Highly Correlated Variables

# %%
print(correlation_matrix[(correlation_matrix > 0.8) & (correlation_matrix!=1)])
# Out:
#                                   BALANCE  BALANCE_FREQUENCY  PURCHASES  \
# BALANCE                               NaN                NaN        NaN
# BALANCE_FREQUENCY                     NaN                NaN        NaN
# PURCHASES                             NaN                NaN        NaN
# ONEOFF_PURCHASES                      NaN                NaN    0.91678
# INSTALLMENTS_PURCHASES                NaN                NaN        NaN
# CASH_ADVANCE                          NaN                NaN        NaN
# PURCHASES_FREQUENCY                   NaN                NaN        NaN
# ONEOFF_PURCHASES_FREQUENCY            NaN                NaN        NaN
# PURCHASES_INSTALLMENTS_FREQUENCY      NaN                NaN        NaN
# CASH_ADVANCE_FREQUENCY                NaN                NaN        NaN
# CASH_ADVANCE_TRX                      NaN                NaN        NaN
# PURCHASES_TRX                         NaN                NaN        NaN
# CREDIT_LIMIT                          NaN                NaN        NaN
# PAYMENTS                              NaN                NaN        NaN
# MINIMUM_PAYMENTS                      NaN                NaN        NaN
# PRC_FULL_PAYMENT                      NaN                NaN        NaN
# TENURE                                NaN                NaN        NaN
#
#                                   ONEOFF_PURCHASES  INSTALLMENTS_PURCHASES  \
# BALANCE                                        NaN                     NaN
# BALANCE_FREQUENCY                              NaN                     NaN
# PURCHASES                                  0.91678                     NaN
# ONEOFF_PURCHASES                               NaN                     NaN
# INSTALLMENTS_PURCHASES                         NaN                     NaN
# CASH_ADVANCE                                   NaN                     NaN
# PURCHASES_FREQUENCY                            NaN                     NaN
# ONEOFF_PURCHASES_FREQUENCY                     NaN                     NaN
# PURCHASES_INSTALLMENTS_FREQUENCY               NaN                     NaN
# CASH_ADVANCE_FREQUENCY                         NaN                     NaN
# CASH_ADVANCE_TRX                               NaN                     NaN
# PURCHASES_TRX                                  NaN                     NaN
# CREDIT_LIMIT                                   NaN                     NaN
# PAYMENTS                                       NaN                     NaN
# MINIMUM_PAYMENTS                               NaN                     NaN
# PRC_FULL_PAYMENT                               NaN                     NaN
# TENURE                                         NaN                     NaN
#
#                                   CASH_ADVANCE  PURCHASES_FREQUENCY  \
# BALANCE                                    NaN                  NaN
# BALANCE_FREQUENCY                          NaN                  NaN
# PURCHASES                                  NaN                  NaN
# ONEOFF_PURCHASES                           NaN                  NaN
# INSTALLMENTS_PURCHASES                     NaN                  NaN
# CASH_ADVANCE                               NaN                  NaN
# PURCHASES_FREQUENCY                        NaN                  NaN
# ONEOFF_PURCHASES_FREQUENCY                 NaN                  NaN
# PURCHASES_INSTALLMENTS_FREQUENCY           NaN             0.862338
# CASH_ADVANCE_FREQUENCY                     NaN                  NaN
# CASH_ADVANCE_TRX                           NaN                  NaN
# PURCHASES_TRX                              NaN                  NaN
# CREDIT_LIMIT                               NaN                  NaN
# PAYMENTS                                   NaN                  NaN
# MINIMUM_PAYMENTS                           NaN                  NaN
# PRC_FULL_PAYMENT                           NaN                  NaN
# TENURE                                     NaN                  NaN
#
#                                   ONEOFF_PURCHASES_FREQUENCY  \
# BALANCE                                                  NaN
# BALANCE_FREQUENCY                                        NaN
# PURCHASES                                                NaN
# ONEOFF_PURCHASES                                         NaN
# INSTALLMENTS_PURCHASES                                   NaN
# CASH_ADVANCE                                             NaN
# PURCHASES_FREQUENCY                                      NaN
# ONEOFF_PURCHASES_FREQUENCY                               NaN
# PURCHASES_INSTALLMENTS_FREQUENCY                         NaN
# CASH_ADVANCE_FREQUENCY                                   NaN
# CASH_ADVANCE_TRX                                         NaN
# PURCHASES_TRX                                            NaN
# CREDIT_LIMIT                                             NaN
# PAYMENTS                                                 NaN
# MINIMUM_PAYMENTS                                         NaN
# PRC_FULL_PAYMENT                                         NaN
# TENURE                                                   NaN
#
#                                   PURCHASES_INSTALLMENTS_FREQUENCY  \
# BALANCE                                                        NaN
# BALANCE_FREQUENCY                                              NaN
# PURCHASES                                                      NaN
# ONEOFF_PURCHASES                                               NaN
# INSTALLMENTS_PURCHASES                                         NaN
# CASH_ADVANCE                                                   NaN
# PURCHASES_FREQUENCY                                       0.862338
# ONEOFF_PURCHASES_FREQUENCY                                     NaN
# PURCHASES_INSTALLMENTS_FREQUENCY                               NaN
# CASH_ADVANCE_FREQUENCY                                         NaN
# CASH_ADVANCE_TRX                                               NaN
# PURCHASES_TRX                                                  NaN
# CREDIT_LIMIT                                                   NaN
# PAYMENTS                                                       NaN
# MINIMUM_PAYMENTS                                               NaN
# PRC_FULL_PAYMENT                                               NaN
# TENURE                                                         NaN
#
#                                   CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  \
# BALANCE                                              NaN               NaN
# BALANCE_FREQUENCY                                    NaN               NaN
# PURCHASES                                            NaN               NaN
# ONEOFF_PURCHASES                                     NaN               NaN
# INSTALLMENTS_PURCHASES                               NaN               NaN
# CASH_ADVANCE                                         NaN               NaN
# PURCHASES_FREQUENCY                                  NaN               NaN
# ONEOFF_PURCHASES_FREQUENCY                           NaN               NaN
# PURCHASES_INSTALLMENTS_FREQUENCY                     NaN               NaN
# CASH_ADVANCE_FREQUENCY                               NaN               NaN
# CASH_ADVANCE_TRX                                     NaN               NaN
# PURCHASES_TRX                                        NaN               NaN
# CREDIT_LIMIT                                         NaN               NaN
# PAYMENTS                                             NaN               NaN
# MINIMUM_PAYMENTS                                     NaN               NaN
# PRC_FULL_PAYMENT                                     NaN               NaN
# TENURE                                               NaN               NaN
#
#                                   PURCHASES_TRX  CREDIT_LIMIT  PAYMENTS  \
# BALANCE                                     NaN           NaN       NaN
# BALANCE_FREQUENCY                           NaN           NaN       NaN
# PURCHASES                                   NaN           NaN       NaN
# ONEOFF_PURCHASES                            NaN           NaN       NaN
# INSTALLMENTS_PURCHASES                      NaN           NaN       NaN
# CASH_ADVANCE                                NaN           NaN       NaN
# PURCHASES_FREQUENCY                         NaN           NaN       NaN
# ONEOFF_PURCHASES_FREQUENCY                  NaN           NaN       NaN
# PURCHASES_INSTALLMENTS_FREQUENCY            NaN           NaN       NaN
# CASH_ADVANCE_FREQUENCY                      NaN           NaN       NaN
# CASH_ADVANCE_TRX                            NaN           NaN       NaN
# PURCHASES_TRX                               NaN           NaN       NaN
# CREDIT_LIMIT                                NaN           NaN       NaN
# PAYMENTS                                    NaN           NaN       NaN
# MINIMUM_PAYMENTS                            NaN           NaN       NaN
# PRC_FULL_PAYMENT                            NaN           NaN       NaN
# TENURE                                      NaN           NaN       NaN
#
#                                   MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# BALANCE                                        NaN               NaN     NaN
# BALANCE_FREQUENCY                              NaN               NaN     NaN
# PURCHASES                                      NaN               NaN     NaN
# ONEOFF_PURCHASES                               NaN               NaN     NaN
# INSTALLMENTS_PURCHASES                         NaN               NaN     NaN
# CASH_ADVANCE                                   NaN               NaN     NaN
# PURCHASES_FREQUENCY                            NaN               NaN     NaN
# ONEOFF_PURCHASES_FREQUENCY                     NaN               NaN     NaN
# PURCHASES_INSTALLMENTS_FREQUENCY               NaN               NaN     NaN
# CASH_ADVANCE_FREQUENCY                         NaN               NaN     NaN
# CASH_ADVANCE_TRX                               NaN               NaN     NaN
# PURCHASES_TRX                                  NaN               NaN     NaN
# CREDIT_LIMIT                                   NaN               NaN     NaN
# PAYMENTS                                       NaN               NaN     NaN
# MINIMUM_PAYMENTS                               NaN               NaN     NaN
# PRC_FULL_PAYMENT                               NaN               NaN     NaN
# TENURE                                         NaN               NaN     NaN

# %%
# Set self correlation as ZERO(0)
correlation_matrix.abs()
correlation_matrix[correlation_matrix == 1] = 0

# %%
correlation_columns = correlation_matrix.max().sort_values(ascending=False)

# %%
print(correlation_columns[correlation_columns > 0.8])
# Out:
# PURCHASES                           0.916780
# ONEOFF_PURCHASES                    0.916780
# PURCHASES_INSTALLMENTS_FREQUENCY    0.862338
# PURCHASES_FREQUENCY                 0.862338
# dtype: float64

# %% [markdown]
# Therefore Highly correlated variables are:
# PURCHASES and ONEOFF_PURCHASES
# PURCHASES_INSTALLMENTS_FREQUENCY and PURCHASES_FREQUENCY
#
# Since there is no dependent variable in the scenario, we can remove any one variable for our cluster analysis.
#
# Here we will remove ONEOFF_PURCHASES and PURCHASES_INSTALLMENTS_FREQUENCY from the data.

# %%
copyOfData = data.copy()
#data = copyOfData.copy()

# %%
# Removing the columns ONEOFF_PURCHASES and PURCHASES_INSTALLMENTS_FREQUENCY
data = data.drop(columns=["CUST_ID","ONEOFF_PURCHASES","PURCHASES_INSTALLMENTS_FREQUENCY"])
data
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  INSTALLMENTS_PURCHASES  \
# 0       40.900749           0.818182      95.40                   95.40
# 1     3202.467416           0.909091       0.00                    0.00
# 2     2495.148862           1.000000     773.17                    0.00
# 4      817.714335           1.000000      16.00                    0.00
# 5     1809.828751           1.000000    1333.28                 1333.28
# ...           ...                ...        ...                     ...
# 8943     5.871712           0.500000      20.90                    0.00
# 8945    28.493517           1.000000     291.12                  291.12
# 8947    23.398673           0.833333     144.40                  144.40
# 8948    13.457564           0.833333       0.00                    0.00
# 8949   372.708075           0.666667    1093.25                    0.00
#
#       CASH_ADVANCE  PURCHASES_FREQUENCY  ONEOFF_PURCHASES_FREQUENCY  \
# 0         0.000000             0.166667                    0.000000
# 1      6442.945483             0.000000                    0.000000
# 2         0.000000             1.000000                    1.000000
# 4         0.000000             0.083333                    0.083333
# 5         0.000000             0.666667                    0.000000
# ...            ...                  ...                         ...
# 8943      0.000000             0.166667                    0.166667
# 8945      0.000000             1.000000                    0.000000
# 8947      0.000000             0.833333                    0.000000
# 8948     36.558778             0.000000                    0.000000
# 8949    127.040008             0.666667                    0.666667
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                   0.000000                 0              2        1000.0
# 1                   0.250000                 4              0        7000.0
# 2                   0.000000                 0             12        7500.0
# 4                   0.000000                 0              1        1200.0
# 5                   0.000000                 0              8        1800.0
# ...                      ...               ...            ...           ...
# 8943                0.000000                 0              1         500.0
# 8945                0.000000                 0              6        1000.0
# 8947                0.000000                 0              5        1000.0
# 8948                0.166667                 2              0         500.0
# 8949                0.333333                 2             23        1200.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0      201.802084        139.509787          0.000000      12
# 1     4103.032597       1072.340217          0.222222      12
# 2      622.066742        627.284787          0.000000      12
# 4      678.334763        244.791237          0.000000      12
# 5     1400.057770       2407.246035          0.000000      12
# ...           ...               ...               ...     ...
# 8943    58.644883         43.473717          0.000000       6
# 8945   325.594462         48.886365          0.500000       6
# 8947    81.270775         82.418369          0.250000       6
# 8948    52.549959         55.755628          0.250000       6
# 8949    63.165404         88.288956          0.000000       6
#
# [8636 rows x 15 columns]

# %% [markdown]
# ## Feature Scaling

# %%
data.hist(figsize=(18,18))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001AEF2AA1320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AEF2A95C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AEF2AEDE10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AEF2B2B400>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001AEF2B5B9B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AEF2B8EF60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AEF2BCB550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AEF2BFDB38>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001AEF2BFDB70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AEF2C6A6A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AEF2F5CC50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AEF2F99240>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001AEF2FC97F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AEF2FFCDA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AEF303B390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001AEF306A940>]],
#       dtype=object)

# %% [markdown]
# Since the data is not normally/uniformly distributed. We have to normalize the data.
# If the data was normally distributed, we could standardized.

# %%
cnames = data.columns
cnames
# Out:
# Index(['BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES', 'INSTALLMENTS_PURCHASES',
#        'CASH_ADVANCE', 'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY',
#        'CASH_ADVANCE_FREQUENCY', 'CASH_ADVANCE_TRX', 'PURCHASES_TRX',
#        'CREDIT_LIMIT', 'PAYMENTS', 'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT',
#        'TENURE'],
#       dtype='object')

# %%
# Normalizing the data column wise.
for i in cnames:
    data[i] = (data[i] - data[i].min())/(data[i].max() - data[i].min())
    
data
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  INSTALLMENTS_PURCHASES  \
# 0     0.002148           0.818182   0.001945                0.004240
# 1     0.168169           0.909091   0.000000                0.000000
# 2     0.131026           1.000000   0.015766                0.000000
# 4     0.042940           1.000000   0.000326                0.000000
# 5     0.095038           1.000000   0.027188                0.059257
# ...        ...                ...        ...                     ...
# 8943  0.000308           0.500000   0.000426                0.000000
# 8945  0.001496           1.000000   0.005936                0.012939
# 8947  0.001229           0.833333   0.002945                0.006418
# 8948  0.000707           0.833333   0.000000                0.000000
# 8949  0.019572           0.666667   0.022293                0.000000
#
#       CASH_ADVANCE  PURCHASES_FREQUENCY  ONEOFF_PURCHASES_FREQUENCY  \
# 0         0.000000             0.166667                    0.000000
# 1         0.136685             0.000000                    0.000000
# 2         0.000000             1.000000                    1.000000
# 4         0.000000             0.083333                    0.083333
# 5         0.000000             0.666667                    0.000000
# ...            ...                  ...                         ...
# 8943      0.000000             0.166667                    0.166667
# 8945      0.000000             1.000000                    0.000000
# 8947      0.000000             0.833333                    0.000000
# 8948      0.000776             0.000000                    0.000000
# 8949      0.002695             0.666667                    0.666667
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                   0.000000           0.00000       0.005587      0.031720
# 1                   0.166667           0.03252       0.000000      0.232053
# 2                   0.000000           0.00000       0.033520      0.248748
# 4                   0.000000           0.00000       0.002793      0.038397
# 5                   0.000000           0.00000       0.022346      0.058431
# ...                      ...               ...            ...           ...
# 8943                0.000000           0.00000       0.002793      0.015025
# 8945                0.000000           0.00000       0.016760      0.031720
# 8947                0.000000           0.00000       0.013966      0.031720
# 8948                0.111111           0.01626       0.000000      0.015025
# 8949                0.222222           0.01626       0.064246      0.038397
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0     0.003978          0.001826          0.000000     1.0
# 1     0.080892          0.014034          0.222222     1.0
# 2     0.012263          0.008210          0.000000     1.0
# 4     0.013373          0.003204          0.000000     1.0
# 5     0.027602          0.031506          0.000000     1.0
# ...        ...               ...               ...     ...
# 8943  0.001155          0.000569          0.000000     0.0
# 8945  0.006418          0.000640          0.500000     0.0
# 8947  0.001601          0.001078          0.250000     0.0
# 8948  0.001035          0.000729          0.250000     0.0
# 8949  0.001244          0.001155          0.000000     0.0
#
# [8636 rows x 15 columns]

# %% [markdown]
# # Cluster Analysis

# %%
# Find the Optimal number of clusters using elbow method

from sklearn.cluster import KMeans

# Estimate Optimum number of clusters
cluster_range = range(1, 20)
cluster_errors = []

for noOfClusters in cluster_range:
    clusters = KMeans(noOfClusters).fit(data)
    cluster_errors.append(clusters.inertia_)
    
cluster_DF = pd.DataFrame( {"noOfClusters": cluster_range, "cluster_errors": cluster_errors})
cluster_DF
# Out:
#     noOfClusters  cluster_errors
# 0              1     4255.702789
# 1              2     2793.606659
# 2              3     2282.698388
# 3              4     1940.126244
# 4              5     1708.132654
# 5              6     1493.976409
# 6              7     1335.677487
# 7              8     1227.817578
# 8              9     1136.251418
# 9             10     1058.418597
# 10            11     1000.404231
# 11            12      957.585100
# 12            13      920.954332
# 13            14      893.398098
# 14            15      855.569806
# 15            16      843.319312
# 16            17      817.367329
# 17            18      796.057932
# 18            19      782.679556

# %% [markdown]
# ### Plotting Elbow Graph

# %%
plt.figure(figsize=(18, 6))
plt.plot(cluster_DF.noOfClusters, cluster_DF.cluster_errors, marker = 'o')
plt.xlabel('K')
plt.ylabel('ERROR')
plt.title('Elbow Graph')
# Out:
# Text(0.5, 1.0, 'Elbow Graph')

# %% [markdown]
# #### Creating the KMeans Model

# %%
# Cluster Size
cluster_size = 4

# %%
# Creating the Model
kmeans_model = KMeans(n_clusters = cluster_size).fit(data)

# %%
#kmeans_model.labels_

# %%
#pd.crosstab(copyOfData['CUST_ID'], kmeans_model.labels_)

# %%
# Merge Actual data and Derived KPI's into one Table

#columns_to_merge = data_KPI.columns.difference(copyOfData.columns)
cluster_data = pd.merge(copyOfData, data_KPI, on = 'CUST_ID')
cluster_data['cluster'] = kmeans_model.labels_
cluster_data
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10005   817.714335           1.000000      16.00             16.00
# 4     C10006  1809.828751           1.000000    1333.28              0.00
# ...      ...          ...                ...        ...               ...
# 8631  C19184     5.871712           0.500000      20.90             20.90
# 8632  C19186    28.493517           1.000000     291.12              0.00
# 8633  C19188    23.398673           0.833333     144.40              0.00
# 8634  C19189    13.457564           0.833333       0.00              0.00
# 8635  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# 1                       0.00   6442.945483             0.000000
# 2                       0.00      0.000000             1.000000
# 3                       0.00      0.000000             0.083333
# 4                    1333.28      0.000000             0.666667
# ...                      ...           ...                  ...
# 8631                    0.00      0.000000             0.166667
# 8632                  291.12      0.000000             1.000000
# 8633                  144.40      0.000000             0.833333
# 8634                    0.00     36.558778             0.000000
# 8635                    0.00    127.040008             0.666667
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  ...  \
# 0                       0.000000                          0.083333  ...
# 1                       0.000000                          0.000000  ...
# 2                       1.000000                          0.000000  ...
# 3                       0.083333                          0.000000  ...
# 4                       0.000000                          0.583333  ...
# ...                          ...                               ...  ...
# 8631                    0.166667                          0.000000  ...
# 8632                    0.000000                          0.833333  ...
# 8633                    0.000000                          0.666667  ...
# 8634                    0.000000                          0.000000  ...
# 8635                    0.666667                          0.000000  ...
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE  \
# 0      201.802084        139.509787          0.000000      12
# 1     4103.032597       1072.340217          0.222222      12
# 2      622.066742        627.284787          0.000000      12
# 3      678.334763        244.791237          0.000000      12
# 4     1400.057770       2407.246035          0.000000      12
# ...           ...               ...               ...     ...
# 8631    58.644883         43.473717          0.000000       6
# 8632   325.594462         48.886365          0.500000       6
# 8633    81.270775         82.418369          0.250000       6
# 8634    52.549959         55.755628          0.250000       6
# 8635    63.165404         88.288956          0.000000       6
#
#       Monthly_Average_Purchase  Monthly_Cash_Advance  Purchase_Type  \
# 0                     7.950000              0.000000    installment
# 1                     0.000000            536.912124        not any
# 2                    64.430833              0.000000        one_off
# 3                     1.333333              0.000000        one_off
# 4                   111.106667              0.000000    installment
# ...                        ...                   ...            ...
# 8631                  3.483333              0.000000        one_off
# 8632                 48.520000              0.000000    installment
# 8633                 24.066667              0.000000    installment
# 8634                  0.000000              6.093130        not any
# 8635                182.208333             21.173335        one_off
#
#       Limit_Usage  Pymt_to_minPymt_Ratio  cluster
# 0        0.040901               1.446508        2
# 1        0.457495               3.826241        2
# 2        0.332687               0.991682        1
# 3        0.681429               2.771075        2
# 4        1.005460               0.581601        0
# ...           ...                    ...      ...
# 8631     0.011743               1.348973        2
# 8632     0.028494               6.660231        3
# 8633     0.023399               0.986076        0
# 8634     0.026915               0.942505        2
# 8635     0.310590               0.715439        0
#
# [8636 rows x 24 columns]

# %%
cluster_data.shape
# Out:
# (8636, 24)

# %%
cluster_data = cluster_data.sort_values(by = 'cluster')
cluster_data
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 8635  C19190   372.708075           0.666667    1093.25           1093.25
# 2829  C13035   978.567283           1.000000    1401.54              0.00
# 6841  C17261   274.604824           1.000000     341.37              0.00
# 6840  C17260  1717.662673           1.000000     209.62              0.00
# 6834  C17254  1212.237847           1.000000     400.00              0.00
# ...      ...          ...                ...        ...               ...
# 3592  C13832    40.467471           1.000000     553.48              0.00
# 6373  C16773   207.099447           1.000000    1764.00              0.00
# 1259  C11397   148.826903           0.727273    3386.58           3386.58
# 1247  C11384   162.905422           0.727273    1600.00              0.00
# 1567  C11718   104.572870           1.000000     937.56            630.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 8635                    0.00    127.040008             0.666667
# 2829                 1401.54      0.000000             1.000000
# 6841                  341.37      0.000000             0.583333
# 6840                  209.62   1425.661833             0.666667
# 6834                  400.00   1141.617933             1.000000
# ...                      ...           ...                  ...
# 3592                  553.48      0.000000             1.000000
# 6373                 1764.00      0.000000             1.000000
# 1259                    0.00     47.494639             0.583333
# 1247                 1600.00      0.000000             0.666667
# 1567                  307.56      0.000000             0.666667
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  ...  \
# 8635                    0.666667                          0.000000  ...
# 2829                    0.000000                          1.000000  ...
# 6841                    0.000000                          0.500000  ...
# 6840                    0.000000                          0.583333  ...
# 6834                    0.000000                          0.900000  ...
# ...                          ...                               ...  ...
# 3592                    0.000000                          1.000000  ...
# 6373                    0.000000                          1.000000  ...
# 1259                    0.583333                          0.000000  ...
# 1247                    0.000000                          0.666667  ...
# 1567                    0.083333                          0.666667  ...
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE  \
# 8635    63.165404         88.288956          0.000000       6
# 2829  1769.181653        302.284864          0.000000      12
# 6841   101.053841        171.581036          0.000000      12
# 6840   559.604995        973.486914          0.000000      12
# 6834   424.376685       1480.270923          0.000000      10
# ...           ...               ...               ...     ...
# 3592   532.936499        176.388863          1.000000      12
# 6373  1667.797657       2090.378842          0.545455      12
# 1259  4474.571671        138.674322          1.000000      12
# 1247  2733.152899        156.243291          0.666667      12
# 1567   870.874657        179.369855          0.583333      12
#
#       Monthly_Average_Purchase  Monthly_Cash_Advance  Purchase_Type  \
# 8635                182.208333             21.173335        one_off
# 2829                116.795000              0.000000    installment
# 6841                 28.447500              0.000000    installment
# 6840                 17.468333            118.805153    installment
# 6834                 40.000000            114.161793    installment
# ...                        ...                   ...            ...
# 3592                 46.123333              0.000000    installment
# 6373                147.000000              0.000000    installment
# 1259                282.215000              3.957887        one_off
# 1247                133.333333              0.000000    installment
# 1567                 78.130000              0.000000           both
#
#       Limit_Usage  Pymt_to_minPymt_Ratio  cluster
# 8635     0.310590               0.715439        0
# 2829     0.217459               5.852697        0
# 6841     0.109842               0.588957        0
# 6840     0.572554               0.574846        0
# 6834     1.010198               0.286689        0
# ...           ...                    ...      ...
# 3592     0.003519               3.021373        3
# 6373     0.517749               0.797845        3
# 1259     0.009020              32.266764        3
# 1247     0.027151              17.492930        3
# 1567     0.017429               4.855190        3
#
# [8636 rows x 24 columns]

# %%
# Value Counts
print(cluster_data['cluster'].value_counts().sort_index())

# Bar Graph showing Number of clients by Clusters
cluster_data['cluster'].value_counts().sort_index().plot.bar(figsize = (15, 5), title='Number of Clients by Cluster')
# Out:
# 0    2481
# 1    1275
# 2    3905
# 3     975
# Name: cluster, dtype: int64

# %%
# Seperating Clients belonging to Different Clusters
for i in range(0, cluster_size):
    globals()['cluster_%s' % i] = pd.DataFrame(cluster_data[cluster_data['cluster'] == i])

# %%
cluster_0.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   2481.000000        2481.000000   2481.000000       2481.000000
# mean    1572.527743           0.941980   1054.908347        394.629000
# std     2009.271403           0.145507   1226.156695        711.950077
# min        0.000000           0.000000     12.000000          0.000000
# 25%      208.127012           1.000000    363.380000          0.000000
# 50%      955.184754           1.000000    671.360000         87.900000
# 75%     1980.103629           1.000000   1337.180000        518.440000
# max    16115.596400           1.000000  22500.000000       9661.370000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             2481.000000   2481.000000          2481.000000
# mean               660.865071    732.278686             0.802753
# std                944.850874   1921.737507             0.199416
# min                  0.000000      0.000000             0.416667
# 25%                204.800000      0.000000             0.583333
# 50%                410.900000      0.000000             0.833333
# 75%                807.720000    631.332476             1.000000
# max              22500.000000  47137.211760             1.000000
#
#        ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# count                 2481.000000                       2481.000000
# mean                     0.153816                          0.696809
# std                      0.178430                          0.304148
# min                      0.000000                          0.000000
# 25%                      0.000000                          0.500000
# 50%                      0.083333                          0.750000
# 75%                      0.250000                          1.000000
# max                      0.666667                          1.000000
#
#        CASH_ADVANCE_FREQUENCY  ...  CREDIT_LIMIT      PAYMENTS  \
# count             2481.000000  ...   2481.000000   2481.000000
# mean                 0.104075  ...   4069.496456   1474.506334
# std                  0.183232  ...   3332.100106   2138.072210
# min                  0.000000  ...    300.000000     18.496532
# 25%                  0.000000  ...   1500.000000    430.736402
# 50%                  0.000000  ...   3000.000000    866.683765
# 75%                  0.166667  ...   6000.000000   1741.315136
# max                  1.000000  ...  23000.000000  40627.595240
#
#        MINIMUM_PAYMENTS  PRC_FULL_PAYMENT       TENURE  \
# count       2481.000000       2481.000000  2481.000000
# mean        1114.612280          0.054437    11.590891
# std         3177.643356          0.105007     1.240407
# min            0.019163          0.000000     6.000000
# 25%          175.055337          0.000000    12.000000
# 50%          379.581910          0.000000    12.000000
# 75%         1007.132278          0.083333    12.000000
# max        76406.207520          0.500000    12.000000
#
#        Monthly_Average_Purchase  Monthly_Cash_Advance  Limit_Usage  \
# count               2481.000000           2481.000000  2481.000000
# mean                  90.839644             66.207918     0.428134
# std                  103.686589            173.120177     0.367684
# min                    1.000000              0.000000     0.000000
# 25%                   32.000000              0.000000     0.070416
# 50%                   58.820000              0.000000     0.341943
# 75%                  115.463333             57.070067     0.775134
# max                 1875.000000           3928.100980     2.033580
#
#        Pymt_to_minPymt_Ratio  cluster
# count            2481.000000   2481.0
# mean               12.403229      0.0
# std               204.818359      0.0
# min                 0.001848      0.0
# 25%                 0.904216      0.0
# 50%                 1.739699      0.0
# 75%                 4.666277      0.0
# max              6840.528861      0.0
#
# [8 rows x 22 columns]

# %%
cluster_1.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   1275.000000        1275.000000   1275.000000       1275.000000
# mean    2038.786966           0.984438   3438.569357       2515.207678
# std     2545.153782           0.063841   4212.521007       3392.786013
# min        0.413670           0.181818      8.400000          8.400000
# 25%      317.235151           1.000000   1256.880000        865.195000
# 50%     1023.124791           1.000000   2352.200000       1597.670000
# 75%     2779.140091           1.000000   4106.030000       2828.590000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             1275.000000   1275.000000          1275.000000
# mean               923.361678    691.118585             0.934103
# std               1490.421013   2065.938677             0.108842
# min                  0.000000      0.000000             0.583333
# 25%                 29.460000      0.000000             0.916667
# 50%                451.410000      0.000000             1.000000
# 75%               1169.365000    334.353733             1.000000
# max              15497.190000  29282.109150             1.000000
#
#        ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# count                 1275.000000                       1275.000000
# mean                     0.829150                          0.541699
# std                      0.167911                          0.400025
# min                      0.416667                          0.000000
# 25%                      0.666667                          0.083333
# 50%                      0.833333                          0.583333
# 75%                      1.000000                          1.000000
# max                      1.000000                          1.000000
#
#        CASH_ADVANCE_FREQUENCY  ...  CREDIT_LIMIT      PAYMENTS  \
# count             1275.000000  ...   1275.000000   1275.000000
# mean                 0.094725  ...   6917.780392   3479.458540
# std                  0.188283  ...   4326.741155   4440.551866
# min                  0.000000  ...    300.000000     66.610309
# 25%                  0.000000  ...   3500.000000   1150.515498
# 50%                  0.000000  ...   6500.000000   2096.121508
# 75%                  0.083333  ...   9450.000000   4006.871976
# max                  1.000000  ...  30000.000000  46930.598240
#
#        MINIMUM_PAYMENTS  PRC_FULL_PAYMENT       TENURE  \
# count       1275.000000       1275.000000  1275.000000
# mean         803.598349          0.255686    11.783529
# std         1400.791915          0.356245     0.924231
# min            3.197940          0.000000     6.000000
# 25%          186.372366          0.000000    12.000000
# 50%          312.026316          0.000000    12.000000
# 75%          923.670302          0.449494    12.000000
# max        21235.065300          1.000000    12.000000
#
#        Monthly_Average_Purchase  Monthly_Cash_Advance  Limit_Usage  \
# count               1275.000000           1275.000000  1275.000000
# mean                 291.565995             61.316400     0.317821
# std                  354.643679            189.678655     0.288706
# min                    0.700000              0.000000     0.000069
# 25%                  107.176667              0.000000     0.063212
# 50%                  200.059167              0.000000     0.236173
# 75%                  348.851250             29.529324     0.514695
# max                 4086.630833           2693.865496     1.075859
#
#        Pymt_to_minPymt_Ratio  cluster
# count            1275.000000   1275.0
# mean                9.630575      1.0
# std                12.617084      0.0
# min                 0.126426      1.0
# 25%                 1.829645      1.0
# 50%                 5.756152      1.0
# 75%                12.762430      1.0
# max               207.643990      1.0
#
# [8 rows x 22 columns]

# %%
cluster_2.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   3905.000000        3905.000000   3905.000000       3905.000000
# mean    1849.312934           0.863523    225.618848        185.006149
# std     2084.291693           0.239658    728.909714        685.695311
# min        0.000000           0.000000      0.000000          0.000000
# 25%      394.269079           0.818182      0.000000          0.000000
# 50%     1179.878115           1.000000      7.260000          0.000000
# 75%     2487.423060           1.000000    208.000000        140.030000
# max    16304.889250           1.000000  22101.780000      22101.780000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             3905.000000   3905.000000          3905.000000
# mean                40.744446   1483.626387             0.103404
# std                243.853038   2364.009893             0.131551
# min                  0.000000      0.000000             0.000000
# 25%                  0.000000      0.000000             0.000000
# 50%                  0.000000    513.751922             0.083333
# 75%                  0.000000   1998.061069             0.166667
# max              12541.000000  26194.049540             0.500000
#
#        ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# count                 3905.000000                       3905.000000
# mean                     0.060286                          0.042236
# std                      0.093938                          0.099104
# min                      0.000000                          0.000000
# 25%                      0.000000                          0.000000
# 50%                      0.000000                          0.000000
# 75%                      0.083333                          0.000000
# max                      0.444444                          0.500000
#
#        CASH_ADVANCE_FREQUENCY  ...  CREDIT_LIMIT      PAYMENTS  \
# count             3905.000000  ...   3905.000000   3905.000000
# mean                 0.204344  ...   4117.491561   1527.624458
# std                  0.216002  ...   3343.056555   2606.694898
# min                  0.000000  ...     50.000000      0.049513
# 25%                  0.000000  ...   1500.000000    347.568201
# 50%                  0.166667  ...   3000.000000    703.756040
# 75%                  0.333333  ...   6000.000000   1596.674994
# max                  1.500000  ...  23000.000000  50721.483360
#
#        MINIMUM_PAYMENTS  PRC_FULL_PAYMENT       TENURE  \
# count       3905.000000       3905.000000  3905.000000
# mean         894.333360          0.034691    11.473239
# std         2277.516769          0.088845     1.362316
# min            0.055880          0.000000     6.000000
# 25%          194.324456          0.000000    12.000000
# 50%          410.924268          0.000000    12.000000
# 75%          886.322345          0.000000    12.000000
# max        61031.618600          0.833333    12.000000
#
#        Monthly_Average_Purchase  Monthly_Cash_Advance  Limit_Usage  \
# count               3905.000000           3905.000000  3905.000000
# mean                  19.875788            135.294107     0.494876
# std                   62.829676            219.853247     0.422154
# min                    0.000000              0.000000     0.000000
# 25%                    0.000000              0.000000     0.152834
# 50%                    0.806667             45.981448     0.490516
# 75%                   18.125000            180.691323     0.832184
# max                 1841.815000           2381.277231    15.909951
#
#        Pymt_to_minPymt_Ratio  cluster
# count            3905.000000   3905.0
# mean                7.125125      2.0
# std                71.122722      0.0
# min                 0.000730      2.0
# 25%                 0.811598      2.0
# 50%                 1.348973      2.0
# 75%                 4.473031      2.0
# max              2846.533661      2.0
#
# [8 rows x 22 columns]

# %%
cluster_3.describe()
# Out:
#            BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   975.000000         975.000000    975.000000        975.000000
# mean    108.427132           0.784879    998.155692        323.605610
# std     191.505090           0.246537   1508.749523       1114.942379
# min       0.074724           0.090909      0.000000          0.000000
# 25%      24.386077           0.636364    274.960000          0.000000
# 50%      55.243291           0.900000    554.670000          0.000000
# 75%     118.465352           1.000000   1175.430000        185.525000
# max    2980.054695           1.000000  26784.620000      26514.320000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count              975.000000    975.000000           975.000000
# mean               675.287497     96.594011             0.714926
# std                959.446119    672.288754             0.290760
# min                  0.000000      0.000000             0.000000
# 25%                181.060000      0.000000             0.500000
# 50%                401.880000      0.000000             0.800000
# 75%                852.780000      0.000000             1.000000
# max              12375.000000  14048.071810             1.000000
#
#        ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# count                  975.000000                        975.000000
# mean                     0.106696                          0.616156
# std                      0.186052                          0.344635
# min                      0.000000                          0.000000
# 25%                      0.000000                          0.333333
# 50%                      0.000000                          0.666667
# 75%                      0.166667                          0.916667
# max                      0.833333                          1.000000
#
#        CASH_ADVANCE_FREQUENCY  ...  CREDIT_LIMIT      PAYMENTS  \
# count              975.000000  ...    975.000000    975.000000
# mean                 0.011694  ...   4161.418337   1385.455900
# std                  0.056005  ...   3512.155453   2442.937922
# min                  0.000000  ...    300.000000     16.385421
# 25%                  0.000000  ...   1500.000000    376.896792
# 50%                  0.000000  ...   3000.000000    734.613034
# 75%                  0.000000  ...   5600.000000   1513.167647
# max                  0.916667  ...  30000.000000  34107.074990
#
#        MINIMUM_PAYMENTS  PRC_FULL_PAYMENT      TENURE  \
# count        975.000000        975.000000  975.000000
# mean         186.486926          0.799199   11.309744
# std          457.183574          0.200380    1.615015
# min            1.721007          0.333333    6.000000
# 25%          119.497720          0.636364   12.000000
# 50%          153.058328          0.833333   12.000000
# 75%          174.168336          1.000000   12.000000
# max        11853.796130          1.000000   12.000000
#
#        Monthly_Average_Purchase  Monthly_Cash_Advance  Limit_Usage  \
# count                975.000000            975.000000   975.000000
# mean                  87.552896              8.870352     0.035706
# std                  128.287589             58.781017     0.053863
# min                    0.000000              0.000000     0.000075
# 25%                   24.983750              0.000000     0.007684
# 50%                   49.406667              0.000000     0.018003
# 75%                  104.706667              0.000000     0.043124
# max                 2232.051667           1170.672651     0.640216
#
#        Pymt_to_minPymt_Ratio  cluster
# count             975.000000    975.0
# mean               10.134280      3.0
# std                30.770266      0.0
# min                 0.194178      3.0
# 25%                 2.531506      3.0
# 50%                 5.050453      3.0
# 75%                 9.778795      3.0
# max               765.103462      3.0
#
# [8 rows x 22 columns]

# %% [markdown]
# Using the above clusters, the we can Understand the marketing stratergy.

# %% [markdown]
# ___________________________________________________________________________________________

# %% [markdown]
# # DONE
